# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnu-1110/cinefind/blob/main/cv_lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

#to show image
def show_comparison(original,blur3,blur5,blur7):
  plt.figure(figsize=(12,10))

  #original image
  plt.subplot(2,2,1)
  plt.imshow(original,cmap='gray')
  plt.title('Original')
  plt.axis('off')

  #3x3 kernal
  plt.subplot(2,2,2)
  plt.imshow(blur3,cmap='gray')
  plt.title('avg filter (3x3)(Blur3)')
  plt.axis('off')

  #5x5 kernal
  plt.subplot(2,2,3)
  plt.imshow(blur5,cmap='gray')
  plt.title('avg filter (5x5)(Blur5)')
  plt.axis('off')

  #7x7 kernal
  plt.subplot(2,2,4)
  plt.imshow(blur7,cmap='gray')
  plt.title('avg filter (7x7)(Blur7)')
  plt.axis('off')

  plt.tight_layout()
  plt.show()

img = cv2.imread('/content/drive/MyDrive/images2.jpg', 0)
if img is None:
    print("Error: Image not found.")
else:
    karnal_3x3=np.ones((3,3),np.float32)/9
    karnal_5x5=np.ones((5,5),np.float32)/25
    karnal_7x7=np.ones((7,7),np.float32)/49
    blur_3=cv2.filter2D(img,-1,karnal_3x3)
    blur_5=cv2.filter2D(img,-1,karnal_5x5)
    blur_7=cv2.filter2D(img,-1,karnal_7x7)
    show_comparison(img,blur_3,blur_5,blur_7)

# %%
if img is not None:
    # Apply the average filters
    blur3 = cv2.filter2D(img, -1, karnal_3x3)
    blur5 = cv2.filter2D(img, -1, karnal_5x5)
    blur7 = cv2.filter2D(img, -1, karnal_7x7)

    # Display the comparison
    show_comparison(img, blur3, blur5, blur7)
else:
    print("Error: Image was not loaded correctly.")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
